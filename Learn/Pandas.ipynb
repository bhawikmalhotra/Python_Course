# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas Series Object

# %%
import pandas as pd

s1 = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s1)

# Dictonary series 
s2 = pd.Series({'a':10,'b':20,'c':30})


# calculations
s1 + 1
s1 + s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    11.0
# b    22.0
# c    33.0
# d     NaN
# e     NaN
# dtype: float64

# %%
# Dataframe
df = pd.DataFrame({"Name":['Bob','Sam','Anne'],"Marks":[76,25,92]}, index=[1,2,3])
df
# Out:
#    Name  Marks
# 1   Bob     76
# 2   Sam     25
# 3  Anne     92

# %% [markdown]
# Reading csv & Pandas Functions

# %%
file = pd.read_csv('') # enter filename

file.read() # reading file

# Reading functions
file.head()                 # read first 5 rows 
file.tail()                 # read last 5 rows
file.shape                  # returns num of rows & columns
file.descrive               # return description

# %%
# Extract rows and columns
file.iloc['row', 'col']                                     # .iloc - for extracting by index
file.loc['row', ('col1', 'col2')]                           # .loc - for extracting by labels

# Drop 
file.drop('col | row', axis=1, inplace=True)                # axis=1 for columns, axis=0 for rows

# other functions
file.sort_index()                                           # sort by index
file.sort_values(by='colname')                              # sort by column values
file.value_counts('colname')                                # count unique values in column
file.groupby('colname')                                     # group by column values

# .mean(), .sum(), .count(), .min(), .max() etc for calculations

file.to_csv('newfilename.csv', index=False)                 # saving file without index

file['col_name'].apply()                                    # apply function to dataframe

# %%
import pandas as pd

file = pd.read_csv('customers-100.csv')  

file.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
import pandas as pd

file = pd.read_csv('customers-100.csv')

print(file.columns)

file.loc[0:5, ('Customer Id','First Name', 'Last Name',)]


# file.value_counts('Country')
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')
#        Customer Id First Name Last Name
# 0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1  1Ef7b82A4CAAD10    Preston    Lozano
# 2  6F94879bDAfE5a6        Roy     Berry
# 3  5Cef8BFA16c5e3c      Linda     Olsen
# 4  053d585Ab6b3159     Joanna    Bender
# 5  2d08FB17EE273F4      Aimee     Downs
